# %%
import pandas as pd

# %%
df = pd.read_csv('billboard.csv')

print(df.to_string())
# Out:
#         id  chart_date  target_rank  actual_rank                                                                             title                               artist  peak_rank  weeks_on_chart
# 0        1  1987-07-11           82          NaN                                                                               NaN                                  NaN        NaN             NaN
# 1        2  1973-08-04           14          NaN                                                                               NaN                                  NaN        NaN             NaN
# 2        3  1961-07-03           56         57.0                                                                      I Don't Mind                          James Brown       47.0             8.0
# 3        4  1971-08-07           32         31.0                                                               You've Got A Friend         Roberta Flack,Donny Hathaway       29.0            12.0
# ...

# %%
df.isnull()
# Out:
#          id  chart_date  target_rank  ...  artist  peak_rank  weeks_on_chart
# 0     False       False        False  ...    True       True            True
# 1     False       False        False  ...    True       True            True
# 2     False       False        False  ...   False      False           False
# 3     False       False        False  ...   False      False           False
# 4     False       False        False  ...    True       True            True
# ...     ...         ...          ...  ...     ...        ...             ...
# 1295  False       False        False  ...   False      False           False
# 1296  False       False        False  ...   False      False           False
# 1297  False       False        False  ...    True       True            True
# 1298  False       False        False  ...    True       True            True
# 1299  False       False        False  ...   False      False           False
#
# [1300 rows x 8 columns]

# %%
# Making a list of missing value types
missing_values = ["n/a", "na", "--"]
df = pd.read_csv("billboard.csv", na_values = missing_values)

# %%
df.isnull()
# Out:
#          id  chart_date  target_rank  ...  artist  peak_rank  weeks_on_chart
# 0     False       False        False  ...    True       True            True
# 1     False       False        False  ...    True       True            True
# 2     False       False        False  ...   False      False           False
# 3     False       False        False  ...   False      False           False
# 4     False       False        False  ...    True       True            True
# ...     ...         ...          ...  ...     ...        ...             ...
# 1295  False       False        False  ...   False      False           False
# 1296  False       False        False  ...   False      False           False
# 1297  False       False        False  ...    True       True            True
# 1298  False       False        False  ...    True       True            True
# 1299  False       False        False  ...   False      False           False
#
# [1300 rows x 8 columns]

# %%
 df.isnull().sum()
# Out:
# id                  0
# chart_date          0
# target_rank         0
# actual_rank       410
# title             410
# artist            410
# peak_rank         410
# weeks_on_chart    410
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 2050

# %%
df_sorted = df.dropna()
df_sorted
# Out:
#         id  chart_date  ...  peak_rank  weeks_on_chart
# 2        3  1961-07-03  ...       47.0             8.0
# 3        4  1971-08-07  ...       29.0            12.0
# 5        6  1980-08-02  ...        3.0            25.0
# 9       10  1984-03-24  ...       10.0            18.0
# 11      12  1980-11-15  ...        5.0            21.0
# ...    ...         ...  ...        ...             ...
# 1289  1290  1967-04-22  ...        1.0            15.0
# 1291  1292  1963-03-09  ...        1.0            15.0
# 1295  1296  1983-07-02  ...       36.0            13.0
# 1296  1297  1961-03-13  ...        8.0            12.0
# 1299  1300  1991-06-29  ...       72.0             7.0
#
# [890 rows x 8 columns]

# %%
 Artist = df.artist.unique()
 Title = df.title.unique()
 Actual_rank = df.actual_rank.unique()
 Peak_rank = df.peak_rank.unique()
 Weeks_on_chart = df.weeks_on_chart.unique()

# %%
print (Artist)
# Out:
# [nan 'James Brown' 'Roberta Flack,Donny Hathaway' 'Bette Midler'
#  'Billy Joel' 'Johnny Lee' 'Aerosmith' 'Cyndi Lauper'
#  'Daryl Hall & John Oates' 'Tanya Tucker' 'The J. Geils Band'
#  'The 5th Dimension' 'Talking Heads' 'Graham Nash' 'The Chiffons'
#  'Bad Company' 'Steve Miller Band' 'R. Dean Taylor' 'Heart'
#  'Yvonne Elliman' 'Jimi Hendrix' 'Flatt & Scruggs' 'The Rolling Stones'
#  'Snap' 'Five Man Electrical Band' 'Phil Collins' 'The Power Station'
#  'The Staple Singers' 'Barbra Streisand' 'The Beatles' 'Cliff Richard'
#  'Led Zeppelin' 'J. Frank Wilson & The Cavaliers' 'The Robert Cray Band'
#  'Bobbi Martin' 'Peggy Lee' 'Creedence Clearwater Revival' 'Gino Vannelli'
#  'Roy Orbison' 'The Contours' 'Little Joey & The Flips'
#  'Sly & The Family Stone' 'Meat Loaf' 'The Youngbloods'
#  'Martha & The Vandellas' 'Foghat' 'Little River Band' 'The Boys'
#  'Paul Simon' 'UB40' 'Michael Jackson With Siedah Garrett' 'David Bowie'
# ...

# %%
print (Title)
# Out:
# [nan "I Don't Mind" "You've Got A Friend" 'The Rose' 'An Innocent Man'
#  "Lookin' For Love" 'Last Child' 'She Bop' 'Kiss On My List'
#  "Here's Some Love" "Just Can't Wait" 'Never My Love' 'And She Was'
#  'Chicago' "Sweet Talkin' Guy" "Rock 'N' Roll Fantasy" 'The Joker'
#  'Indiana Wants Me' 'Crazy On You' "If I Can't Have You" 'Freedom'
#  'Foggy Mountain Breakdown' "It's Only Rock 'N Roll (But I Like It)"
#  'The Power' 'Absolutely Right' 'Two Hearts' 'Some Like It Hot'
#  "I'll Take You There" 'People' 'Love Me Do' 'Carrie'
#  'Over The Hills And Far Away' 'Last Kiss' 'Smoking Gun' 'I Love You So'
#  'Is That All There Is' 'I Put A Spell On You' 'Hurts To Be In Love'
#  'Cry Softly Lonely One' 'Do You Love Me' 'Bongo Stomp' 'Black Cars'
#  'Hot Fun In The Summertime' 'Paradise By The Dashboard Light'
#  'Get Together' 'Nowhere To Run' "Drivin' Wheel" 'Reminiscing'
#  'Dial My Heart' 'Cold Sweat - Part 1' 'You Can Call Me Al' 'Red Red Wine'
# ...

# %%
print (Actual_rank)
# Out:
# [ nan  57.  31.  16.  51.  63.  21.  39.  55.  87.  90.  19.  36.  86.
#   41.  46.  18. 100.  29.  65.  17.  28.  27.  48.  24.  12.  66.  81.
#   73.  56.  74.  33.  96.  89.  53.  58.  97.  99.  43.   5.  49.  54.
#   69.  34.  10.  42.  60.  85.  14.  11.  22.  62.   8.  83.  32.  52.
#   61.   3.  64.  13.  44.  75.  47.  79.  20.  38.   6.  50.  91.   9.
#   95.  68.  35.   7.  93.  37.  67.  30.  15.  40.  88.   4.  78.  92.
#   71.   2.  26.  98.  82.  25.  94.  70.  76.  72.  80.  77.  84.  59.
#   23.   1.  45.]

# %%
print (Peak_rank)
# Out:
# [ nan  47.  29.   3.  10.   5.  21.   1.  82.  78.  12.  54.  35.  13.
#   59.  55.  16.   2.  26.   6.  34.  51.  22.  70.  11.  58.  57.  52.
#   42.  39.   8.   7.  23.  15.  45.  17.   4.  28.  76.  73.  14.  19.
#   48.  61.  69.   9.  20.  41.  37.  33.  25.  32.  36.  95.  30.  38.
#   93.  72.  49.  40.  56.  24.  77.  27.  80.  94.  75.  92.  44.  74.
#   79.  97.  50.  62.  85.  18.  66.  46.  68.  60.  67.  64.  31.  90.
#   63.  43.  89.  91.  65. 100.]

# %%
print (Weeks_on_chart)
# Out:
# [nan  8. 12. 25. 18. 21. 15. 23.  5. 11. 20. 10. 19. 22. 14.  7.  9.  6.
#  34. 16. 29. 40. 24. 17. 26. 13.  2. 28. 27.  1. 32.  3.  4. 38. 31. 43.
#  36. 44. 39.]

# %%
#view new data frame
df_new = df_sorted[[ 'actual_rank','target_rank', 'peak_rank','weeks_on_chart']]
df_new
# Out:
#       actual_rank  target_rank  peak_rank  weeks_on_chart
# 2            57.0           56       47.0             8.0
# 3            31.0           32       29.0            12.0
# 5            16.0           15        3.0            25.0
# 9            51.0           49       10.0            18.0
# 11           63.0           65        5.0            21.0
# ...           ...          ...        ...             ...
# 1289          2.0            2        1.0            15.0
# 1291         19.0           17        1.0            15.0
# 1295         36.0           34       36.0            13.0
# 1296          9.0            7        8.0            12.0
# 1299         83.0           84       72.0             7.0
#
# [890 rows x 4 columns]

# %%
#standardize the values in each column
df_new = (df_new-df_new.mean())/df_new.std()

# %%
#view new data frame

df_new
# Out:
#       actual_rank  target_rank  peak_rank  weeks_on_chart
# 2        0.418124     0.381969   1.207161       -1.146333
# 3       -0.515523    -0.479852   0.388902       -0.504473
# 5       -1.054166    -1.090309  -0.793026        1.581572
# 9        0.202667     0.130605  -0.474814        0.458317
# 11       0.633581     0.705152  -0.702108        0.939712
# ...           ...          ...        ...             ...
# 1289    -1.556899    -1.557128  -0.883943       -0.023078
# 1291    -0.946438    -1.018490  -0.883943       -0.023078
# 1295    -0.335976    -0.408034   0.707114       -0.344008
# 1296    -1.305533    -1.377582  -0.565732       -0.504473
# 1299     1.351771     1.387427   2.343630       -1.306798
#
# [890 rows x 4 columns]

# %% [markdown]
# Min-max normalization is one of the most common ways to normalize data. For every feature, the minimum value of that feature gets transformed into a 0, the maximum value gets transformed into a 1, and every other value gets transformed into a decimal between 0 and 1.

# %%
# copy the data
df_min_max_scaled = df_new.copy()
  
# apply normalization techniques
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
  
# view normalized data
print(df_min_max_scaled)
# Out:
#       actual_rank  target_rank  peak_rank  weeks_on_chart
# 2        0.565657     0.555556   0.464646        0.162791
# 3        0.303030     0.313131   0.282828        0.255814
# 5        0.151515     0.141414   0.020202        0.558140
# 9        0.505051     0.484848   0.090909        0.395349
# 11       0.626263     0.646465   0.040404        0.465116
# ...           ...          ...        ...             ...
# 1289     0.010101     0.010101   0.000000        0.325581
# 1291     0.181818     0.161616   0.000000        0.325581
# 1295     0.353535     0.333333   0.353535        0.279070
# 1296     0.080808     0.060606   0.070707        0.255814
# 1299     0.828283     0.838384   0.717172        0.139535
#
# [890 rows x 4 columns]

# %%
plot = df_min_max_scaled.head(10)

# %%
import matplotlib.pyplot as plt
plot.plot(kind = 'bar')
